# %%
import sys 
sys.path.append("C:\\Users\\smoot\\Desktop\\Stage Mnemosyne")

# %%
#Importation des différentes fonctions qui servent dans ce script

import functions.functions_data as d
import functions.functions_affichage as a
import functions.functions_cocleogramme as c
from functions.ReccurentNetwork import RecurrentNetwork

from random import randint

from IPython.display import clear_output

from reservoirpy.nodes import Reservoir,FORCE,Ridge
from reservoirpy.mat_gen import Initializer,_scale_spectral_radius,normal
from reservoirpy.observables import spectral_radius
from tqdm import tqdm

from ReccurentNetwork import *

import numpy as np
import copy
from numpy.linalg import eig

import spicy as sp
import matplotlib.pyplot as plt

# %%
#Code importé de ReservoirPy
def _rls(P, x, e):
    """Recursive Least Squares learning rule."""
    k = np.dot(P, x)
    xPx = np.dot(x.T, k)
    c = float(1.0 / (1.0 + xPx))
    P = P - c * np.outer(k, k)
    dw = -c * np.outer(e, k)

    return dw, P

# %% [markdown]
# # Réseaux de neurones

# %% [markdown]
# On cherche ici dans un premier temps à reprdoduire les figures les plus simples de l'article.
#
# Les mesures de l'article sont effectuées sur 2 réservoirs $ :
#
#   - le premier est dit entrainé : on va alors entrainer le réservoir et la sortie
#   - le second lui est dit non entrainé : on entraine seulement la sortie
#
#
# Ce premier script s'intéresse donc à la reproduction de l'entrainement des figures 3, 4 et 5 ainsi qu'aux résultas obtenus sur un réservoir entrainé.

# %% [markdown]
# ## Expériences

# %% [markdown]
# Deux expériences quasiment similaires sont proposés pour un réservoir totalement entrainé. La seule différence entre ces dernières sont le nombre de neurones utilisés dans le réservoir :
#
#    - Soit N = 2100 pour des résultats robustes entre toutes les données pour un sujet
#    - Soit N = 4000 pour des résultats robustes entre tous les sujets (5 au maximum)
#
# Nous traiterons le premier  cas dans ce papier.
#
# ##### Méthode d'entrainement
#
# Pour ce qui est de l'entrainement du réservoir nous allons procéder comme ceci : nous séparons notre entrée en deux parties : l'époque sensorielle et l'époque motricielle.
#
# ###### Epoque sensorielle :
#
# Pour un sujet donné et parmit toutes les entrées différentes, pour chaque chiffre on selectionne une entrée moyenne. Cette entrée est injectée dans le réservoir sans bruit et sans target, on obtient alors une trajectoire resultante de taille (Timesteps x Nombre de neurones) pour chaque chiffre. Ces 10 trajectoires sont appelées les "innate trajectories" et seront les targets pour toutes les autres entrées durant l'entrainement du l'époque sensorielle en faisant bien attention à  ce que la dimension d'entrée des nouvelles entrées soit cohérente avec celle de l'innate trajectorie, on procédera alors pas une déformation linéaire de l'innate trajectory. De plus, du bruit sera présent durant l'entrainement.
#
# ###### Epoque motrice
#
# On met dans le réservoir une matrice nulle (entrée à 0) et la target de l'époque motrice est l'activité autonome générée par le réservoir sur une durée comprenant la transition époque sensorielle/motrice et l'époque motrice.
# Pour récupérer notre matrice, on utilisera la fonction target_xyz avec comme paramètre, innate = True
#
# ##### Entrainement
#
# On concatene maintenant l'innate trajectory de l'époque sensorielle et de l'époque motrice pour obtenir nos targets finales.
#
# À noter, que chaque entrainement et test commence à -100ms avec le réseau initialisé selon une loi uniform de -1 à 1.
# --> On laisse tourner le réservoir pendant 100ms à blanc ouis on met les entrées ????

# %% [markdown]
# ###### Test
# Les test effectués dans ce script seront fait sur le sujet 1

# %% [markdown]
# Données générales

# %%
data = d.extract_data() #Données d'entrée
transcription = d.extract_target() #Données d'arrivée 

#Les données suivantes sont utilisés dans les fonctions mais pas dans le script ! 

freq_ent = 6*10**3  #fréquence d'entrée
T_ent = 1/freq_ent  #période d'entrée

freq_out = 10**3 #fréquence de sortie 
T_out = 1/freq_out #période de sortie

ampl_int = 5 #Amplitude d'entrée

# %% [markdown]
# Données du réservoir

# %%
N = 2100//7 #Nombre de neurones dans le réservoir
M = 12 #Nombres d'entrées
No = 3 #Nombres de sorties
tau = 25*10e-3
dt = 1e-3
lr = dt/tau
sr = 1.6 #spectral radius --> gain ?
g = 1.6 #le gain du réseau ?                             #je comprends pas trop cette donnée. 
pc = 0.2 # connectivité entre les neurones (pc dans l'article)
SD = g/np.sqrt(pc*N)
mu = 0
I0 = 0.005
biais = 0.2

Wout = normal(No,N,loc=mu,scale = 1/np.sqrt(N))    #Matrice de sortie

# %% [markdown]
# Création de la matrice du réservoir : avec pas d'autapse
# Puis bricolage pour réxupérer le rayon spectral voulu

# %%
c.W_r.init = Initializer(c.W_r)

W = _scale_spectral_radius(c.W_r.init, [N,N], sr)
W = W.toarray()

# %% [markdown]
# Création de la matrice d'entrée : chaque entrée k est projetée sur le neurone $(k-1)\frac{N}{M} + 1$ jusqu'au neurone $k\frac{N}{M}$ selon une loi normale

# %%
Win = c.W_in(N,M)

# %% [markdown]
# Création des réservoirs

# %%
#Réservoir que l'on va entrainer
W_reservoir = copy.deepcopy(W)
reservoir_train = Reservoir(W=W_reservoir,Win=Win,equation='external',input_bias=False)

#Réservoir que l'on ne va pas entrainer 
reservoir_innate = reservoir_train.copy()

# %% [markdown]
# # Trajectoire inée

# %% [markdown]
# Récupération des cocleograms avec une taille maximale pour chaque chiffre

# %%
#Liste qui va contenir tout les cocleogramme maximums pour chaque chiffre
max_cocleogram =[]

for i in range(10):
    
    #Récupération des indices du cocléogramme le plus grand du chiffre i
    indS,indU,indD = c.ind_max_entrance(i,data)
    
    #Ajout à la liste
    max_cocleogram.append(c.entrance_cocleogram(indS,indS,indD,data,transcription).T)

# %% [markdown]
# Détermination des trajectoires inées

# %%
#Liste qui va contenir toutes les trajectoires innées
innate_trajectories = []

for i in range(len(max_cocleogram)):
    
    #Récupération des trajectoires innées 
    initial_trajectory = reservoir_innate.run(max_cocleogram[i])
    
    #Ensuite on les ajoute
    innate_trajectories.append(initial_trajectory)

clear_output()

# %% [markdown]
# Activité de quelques neurones du réservoir sur les trajectoires innées

# %%
fig, ax = plt.subplots(figsize=(15,5))
im = ax.pcolormesh(innate_trajectories[1][:,:100].T,cmap="jet")
fig.colorbar(im,ax = ax)

# %% [markdown]
# # Entrainement du réservoir

# %% [markdown]
# Maintenant que les targets pour les différentes époques sont prêtes, il va falloir concaténer le tout. Donc pour chaque entrée, on va d'abord déformer linéairement la trajectoire innée de l'époque sensorielle, puis, on va ajouter la target de l'époque motrice en concaténant les matrices

# %%
X_input = []
X_target = []
for indS in [1,1,1] : 
    for indU in range(1,4):
        for indD in range(10):
            #Ajout de l'input
            X_input.append(np.transpose(c.entrance_cocleogram(indS, indU, indD,data,transcription)))
            
            #Récupération de la target
            target = innate_trajectories[indD] 

            #Concaténation et ajout dans la target
            X_target.append(target)

# %% [markdown]
# # ReservoirPy

# %% [markdown]
# Définition des valeurs qui vont me servir. Et, dans l'article, seulement 90% des connexions sont modifiées, je définis alors les indices qui ne seront pas modifés

# %%
#Matrice de gain
P = np.identity(N) 

#Matrice de 0, permet de faire tourner le réservoir pendant 100 ms 
blanc = np.zeros((100,12))


#Nombre de connexion qui ne devront pas changer
nbr = int(N*0.1)

#Les indices des connexions qui ne changeront pas 
indice_rows = [randint(0,N-1) for i in range(nbr)]
indice_cols = [randint(0,N-1) for i in range(nbr)]

# %%
np.shape(P[:,1:2])
# Out:
# (300, 1)

# %% [markdown]
# On laisse d'abord tourner le réservoir pendant 100ms (avec une période de 1ms), et on récupère l'état des neurones pour l'injecter dans un réservoir et commencer notre entrainement.

# %%
compt = 0
error_total = []

for xi,xt in tqdm(zip(X_input,X_target)):
    
    #On laisse d'abord le réservoir tourner à vide pendant 100 ms
    #reservoir_train.run(blanc)
    
    #Ensuite on l'entraine
    
    duration = np.shape(xi)[0]
    
    #On calcul la sortie du réservoir pour une entrée xi à un temps t est on obtient la matrice x1
    for t in range(duration):
    
        x1 = reservoir_train.run(xi[t:t+1,:])

        #On calcul l'erreur entre la sortie du réservoir x1 et la valeur cible xt au temps t
        e = x1-xt[t,:]
        
        ###############
        # Partie RLS
        ###############
        x = x1.T
        
        Px = np.dot(P,x)
        
        xtPx = np.dot(x.T,Px)
        
        g = Px/(1+xtPx)
        
        xtP = np.dot(x.T,P)
        
        P = P - np.dot(g,xtP)
        
        dW = np.outer(e,g)
        
        
        #On enlève 10% des changements
        for r,col in zip(indice_rows,indice_cols):
            dW[r,col] = 0
        
        #On enleve les poids réccurents (car des valeurs trop grandes)
        for v in range(N):
            dW[v,v] = 0
        
        W_reservoir -= dW

        #On injecte W dans le réservoir pour les nouveux calculs
        reservoir_train.set_param("W",W_reservoir)
        
        error_total.append(np.mean(e))
        
    
    
    compt += 1
    
    error_total.append(np.mean(e))
    
    print("entrainement {}, moyenne :{}".format(compt,np.mean(e)))

#Affichage de l'évolution des valeurs de l'erreur : 
plt.plot(error_total)
# Out:
# 0it [00:00, ?it/s]
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 658.34it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2454.24it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 848.53it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 647.57it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1422.76it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 8289.14it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3679.21it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1306.64it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 975.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2995.93it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 844.60it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 758.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1537.50it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.36it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 861.43it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1849.34it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 996.51it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 622.49it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 7503.23it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1698.10it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1378.80it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.64it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 994.38it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.07it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1142.24it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 923.65it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.41it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 630.06it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1728.18it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1070.25it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1368.45it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2968.37it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.64it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3591.01it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 971.35it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1091.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1865.79it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.31it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1119.68it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 768.89it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1984.06it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1451.82it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.88it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1119.38it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 997.69it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1338.32it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3415.56it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.07it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1062.66it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1160.57it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 995.33it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1932.86it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 862.85it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1095.40it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3201.76it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 997.69it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 981.58it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1202.50it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1368.90it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 661.67it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1275.64it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2833.99it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.14it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1848.53it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1975.65it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 928.77it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 822.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1702.92it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 952.60it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1215.04it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1338.32it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 594.35it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 859.49it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1107.26it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1664.41it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1168.33it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 593.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 716.36it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1422.76it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1311.95it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1038.19it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1008.97it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 497.49it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1157.69it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1093.98it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1008.49it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 909.43it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.17it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 974.51it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1280.31it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 866.77it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 7219.11it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1079.34it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 941.27it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1079.61it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1731.04it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.86it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.27it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1177.51it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1254.65it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 928.97it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1058.63it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1006.31it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 795.43it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 657.31it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 868.75it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2882.68it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1129.32it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.03it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1736.77it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1979.38it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1061.04it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 840.21it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 914.99it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 883.20it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1466.03it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1981.25it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1225.33it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 782.37it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1368.90it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 909.43it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1134.82it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 5801.25it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.36it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1984.06it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 4223.87it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1096.84it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1644.83it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1266.40it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.41it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 496.48it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1163.79it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1125.08it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.15it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1005.35it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2139.95it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1298.95it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1004.62it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 906.48it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1926.64it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 805.05it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.51it/s]
#
# ...
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 978.61it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3248.88it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1793.20it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1376.08it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3701.95it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 894.31it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.12it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1009.95it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1229.28it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 523.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1172.25it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1927.53it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 328.35it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.11it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1014.10it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1053.85it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 659.17it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3578.76it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.94it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1727.47it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1127.50it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1949.93it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1193.60it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1485.76it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 5801.25it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 869.47it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.60it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1296.54it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 723.53it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.46it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1161.21it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 997.69it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 998.64it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 994.38it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.22it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 979.06it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 3127.74it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1704.31it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1119.68it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1352.13it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1313.59it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1011.65it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 941.06it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1324.80it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1056.23it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1044.40it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1321.46it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1934.64it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 663.76it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1164.44it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1940.01it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 990.16it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1331.10it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 659.79it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.42it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1259.17it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1002.70it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 942.33it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.18it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 999.36it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 970.68it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.41it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1322.71it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1136.36it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 870.91it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 503.28it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1078.78it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1158.01it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 2714.76it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 786.48it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.98it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1345.19it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1468.08it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.90it/s]
#
# Running Reservoir-0: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 926.92it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1003.66it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
#
# Running Reservoir-0:   0%|                                                                       | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
#      32 xtP = np.dot(x.T,P)
#      34 P = P - np.dot(g,xtP)
# ---> 36 dW = np.outer(e,g)
#      39 #On enlève 10% des changements
#      40 for r,col in zip(indice_rows,indice_cols):
#
# File <__array_function__ internals>:180, in outer(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\numeric.py:936, in outer(a, b, out)
#     934 a = asarray(a)
#     935 b = asarray(b)
# --> 936 return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
#
# KeyboardInterrupt:

# %% [markdown]
# Affichage des valeurs propores :

# %%
a.eigein_value(W_reservoir,"W_reservoir",W,"W",)

# %% [markdown]
# Réservoir après training :

# %%
X_test = X_input[0]

X_pred_training = reservoir_train.run(X_test)
X_pred_pre_training = reservoir_innate.run(X_test)

target = X_target[0]

fig,ax = plt.subplots(figsize=(17,10),nrows = 3,ncols=2)

for i in range(3):
    neuron = randint(1,N)
    ax[i,0].plot(X_pred_pre_training[:750,neuron],"b",label = "etat pre-training du neurone " + str(neuron))
    ax[i,0].plot(target[:750,neuron],'--r',label = "innate trajectories")
    ax[i,0].legend()
    
    ax[i,1].plot(X_pred_training[:750,neuron],"b",label = "etat après training du neurone " + str(neuron))
    ax[i,1].plot(target[:750,neuron],'--r',label = "innate trajectories")
    ax[i,1].legend()

# %% [markdown]
# Le réservoir est totalement saturé

# %% [markdown]
# Affichage de la matrice

# %%
fig, ax0= plt.subplots(figsize=(10,10))

im = ax0.pcolormesh(W_reservoir, cmap="jet",)
fig.colorbar(im, ax=ax0)

# %% [markdown]
# # Entrainement de la sortie

# %% [markdown]
# Création des données d'entrainement

# %%
X_input = []
X_target = []
for indS in [1] : 
    for indU in range(1,4):
        for indD in range(10):
            #ajout de l'input
            X_input.append(np.transpose(c.entrance_cocleogram(indS, indU, indD,data,transcription)))
            
            #ajout de la target
            X_target.append(c.target_xyz(indS, indU, indD,data,transcription))

# %% [markdown]
# On crée le modèle

# %%
#Création des différents noeuds
readout_train = FORCE()

#Création du modèle complet
model = reservoir_train >> readout_train

# %% [markdown]
# Ensuite on entraine la sortie, normalement, chaque entrée est entrainée 25 fois

# %%
#Matrice vide
blanc = np.zeros((100,12))

#récupération des données 1 à 1
for xi,xt in tqdm(zip(X_input,X_target)):
    
    #nombre de fois qu'on entraine une entrée 
    nbr_training = 1
    
    for nbr in range(nbr_training):
        
        #On fait d'abord tourner le réservoir à vide
        reservoir_train.run(blanc)
        
        #Entrainement avec le noeud force : méthode online 
        model.train(xi,xt,reset = True)

        
    clear_output()

# %% [markdown]
# Une fois le réservoir entrainé, on le test sur 1 chiffre avec tout les détails.

# %%
#Test du réservoir

#Récupération d'un cocléogramme utilisé durant l'entrainement
indS,indU,indD = 1,3,6
X_test = np.transpose(c.entrance_cocleogram(indS,indU,indD,data,transcription))

#On fait tourner le réservoir
X_pred = model.run(X_test)
    
#récupération des états des neurones
states = c.etat(reservoir_train,indS,indU,indD,data,transcription,1)

#récupération de l'erreur commise sur la trajectoire d'un chiffre
erreur= c.error(X_pred,indS,indU,indD,data,transcription)

# %%
np.shape(X_pred)

# %% [markdown]
# Affichage des résultats

# %%
a.affiche(X_pred,indS,indU,indD,data,transcription,biais = 0,states = states,erreur = erreur,mode = "Online",sr = sr,I0=I0,N=N)

# %% [markdown]
# Ensuite on le test sur les 10 chiffres du même sujet et sur la même entrée

# %%
#Récupération de l'entrée et du sujet
indS,indU= 1,3

chiffre_pred=[]

#On calcule la prédictions pour chacun des 10 chiffres 
for i in range(10):
    
    #Récupération de l'entrée
    X_test = np.transpose(c.entrance_cocleogram(indS,indU,i,data,transcription))
    
    #On fait tourner le réservoir
    chiffre_pred.append(model.run(X_test))
